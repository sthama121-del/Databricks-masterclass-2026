# %% [markdown]
# # Delta Demo — Day 0: Reset
# Run this notebook any time you want a completely clean slate before starting (or re-starting) the Day 1–Day 5 sequence. It removes the demo table's files, the Volume, and the schema entirely. After this runs, `workspace.delta_demo` will not exist at all — the next notebook to run should be **Delta_Demo_Day1_Load**.

# %%
# %sh
rm -rf /Volumes/workspace/delta_demo/demo_files/employees
rm -rf /Volumes/workspace/delta_demo/demo_files/employees_merge_demo

# %%
# %sql
-- Volume will be dropped by the schema CASCADE in the next cell
-- Keeping this as no-op to maintain cell structure
SELECT 'Volume cleanup will be handled by schema drop' AS status;

# %%
# %sql
DROP SCHEMA IF EXISTS workspace.delta_demo CASCADE;

# %% [markdown]
# ### Done
# Everything has been removed. Open **Delta_Demo_Day1_Load** next to start fresh.
